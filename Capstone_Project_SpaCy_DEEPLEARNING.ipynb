# %% [markdown]
# <a href="https://colab.research.google.com/github/lorena-marquez/Fake-News-Project/blob/main/Capstone_Project_SpaCy_DEEPLEARNING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MBA509 Lesson#7 Applications of Deep Learning
#
# This notebook explores:
# * how NLP (SpaCy) are applied to gain insights from documents (unstructured data).
# * How to build Neural Networks: simpleRNN, RNN, LSTMS, CNNs
# * How to apply Convolutional Neural Networks to Detect Actions in Video Advertising
#
# The material also includes a section on how to construct our own AI  using Tensorflow & Keras APIs

# %% [markdown]
# # Natural Language Processing
#
# We will use SpaCy: https://spacy.io/
#
# Primary Tasks:
# * Document Insights: structures, words, similarities, polarities
# * Named Entity Recognition
# * Sentiment Analysis

# %% [markdown]
# # INSTALLATIONS

# %%
# !pip install spacy

# %%
# !pip install SpacyTextBlob

# %%
# !python -m spacy download en_core_web_sm

# %%
import spacy
from spacy import displacy
from IPython.core.display import display, HTML
from spacy.tokens import Span
from spacy.symbols import ORTH
from spacy.lang.en import English

# %% [markdown]
# # SpaCy NLP Process
#
# "This will return a Language object containing all components and data needed to process text. We usually call it nlp. Calling the nlp object on a string of text will return a processed Doc:"

# %% [markdown]
# # The Editorial Data for L'Interdit (translate: The Forbidden) Fragrance

# %% [markdown]
# L'Interdit Eau de Parfum by Givenchy is a Amber Floral fragrance for women. This is a new fragrance. L'Interdit Eau de Parfum was launched in 2018. L'Interdit Eau de Parfum was created by Dominique Ropion, Anne Flipo and Fanny Bal. Top notes are Pear and Bergamot; middle notes are Tuberose, Orange Blossom and Jasmine Sambac; base notes are Patchouli, Vanilla, Ambroxan and Vetiver.

# %% [markdown]
# Among the first perfume creations of the house of Givenchy stands the legendary scent of L'Interdit from 1957, dedicated to actress Audrey Hepburn as the most significant muse of this fashion designer.
#
# In 2018, its new, modern version called L'Interdit Givenchy comes out, developed by perfumers Dominique Ropion, Anne Flipo and Fanny Bal as a floral-woody composition. The perfume is built on the basis of contrast between a bouquet of white flowers (including jasmine, tuberose and orange blossom) and intense woody and earthy notes of patchouli and vetiver. The concept behind the creation is the "thrill of the forbidden" and the challenge of crossing the line.
#
# ACTIVE INGREDIENTS:
#
# "A white floral exalted with a dark accord. The first resolutely underground flower.
# The white notes - orange blossom, jasmin and tuberose - are interlaced with darker more mysterious notes of vetiver and patchouli.
# A generous intense brightness that isn’t afraid of subversion.
# Unforgettable, intense, addictive and fearlessly elegant. The shocking side of chic."
#
# The bottle of thick glass pays homage to the original shape with a more modern outline with the 4 G logo added to the black ribbon that encircles the neck. The face of the new L'Interdit release is actress Rooney Mara. Givenchy L'Interdit is available in 35, 50 and 80 ml Eau de Parfum.

# %% [markdown]
# # The Grammatical Structure - 20 Fake News
#
# *  How are the words related?
#
# "For example, if you’re analyzing text, it makes a huge difference whether a noun is the subject of a sentence, or the object – or whether “google” is used as a verb, or refers to the website or company in a specific context."

# %% [markdown]
# ***1 Fake News***

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("Donald Trump sent his own plane to transport 200 stranded marines.")
displacy.render(doc, style="dep", jupyter=True,  options={'distance': 90})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="c8054fc1bbba40cdbdcd61307832bb21-0" class="displacy" width="1040" height="317.0" direction="ltr" style="max-width: none; height: 317.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Donald</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">Trump</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
# ...

# %%
nlp = spacy.load("en_core_web_sm")
text = "Donald Trump sent his own plane to transport 200 stranded marines."
doc = nlp(text)
sentence_spans = list(doc.sents)
displacy.render(sentence_spans, style="dep", jupyter=True,  options={'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="268721fff3fe432e8ef24a6ff1aea936-0" class="displacy" width="1370" height="377.0" direction="ltr" style="max-width: none; height: 377.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Donald</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">Trump</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
# ...

# %% [markdown]
# ***2 Fake News***

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("FBI director received millions from Clinton Foundation, his brother’s law firm does Clinton’s taxes.")
displacy.render(doc, style="dep", jupyter=True,  options={'distance': 90})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="d1d8d888aadc474b8348411d7ff8e410-0" class="displacy" width="1490" height="317.0" direction="ltr" style="max-width: none; height: 317.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">FBI</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">director</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
# ...

# %%
nlp = spacy.load("en_core_web_sm")
text = "FBI director received millions from Clinton Foundation, his brother’s law firm does Clinton’s taxes."
doc = nlp(text)
sentence_spans = list(doc.sents)
displacy.render(sentence_spans, style="dep", jupyter=True,  options={'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="7982fe141cd1435cb448b1320aa046e5-0" class="displacy" width="1970" height="377.0" direction="ltr" style="max-width: none; height: 377.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">FBI</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">director</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
# ...

# %% [markdown]
# ***3 Fake News***

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("Pope Francis shocks world, endorses Donald Trump for president, Releases Statement.")
displacy.render(doc, style="dep", jupyter=True,  options={'distance': 90})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="8b82c7e473314870beb8499a2b1d67fa-0" class="displacy" width="1040" height="272.0" direction="ltr" style="max-width: none; height: 272.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Pope</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">Francis</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
# ...

# %%
nlp = spacy.load("en_core_web_sm")
text = "Pope Francis shocks world, endorses Donald Trump for president, Releases Statement."
doc = nlp(text)
sentence_spans = list(doc.sents)
displacy.render(sentence_spans, style="dep", jupyter=True,  options={'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="7086e42ff90d4f3b94930263ba320949-0" class="displacy" width="1370" height="317.0" direction="ltr" style="max-width: none; height: 317.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Pope</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">Francis</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
# ...

# %% [markdown]
# ***4 Fake News***

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("Breaking News: China will admit coronavirus coming from its P4 Lab.")
displacy.render(doc, style="dep", jupyter=True,  options={'distance': 90})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="4be86c90d5334401b0392321dc5717b7-0" class="displacy" width="1040" height="272.0" direction="ltr" style="max-width: none; height: 272.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Breaking</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">News:</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
# ...

# %%
nlp = spacy.load("en_core_web_sm")
text = "Breaking News: China will admit coronavirus coming from its P4 Lab."
doc = nlp(text)
sentence_spans = list(doc.sents)
displacy.render(sentence_spans, style="dep", jupyter=True,  options={'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="30508f4873ea42c9a8e06760578c825a-0" class="displacy" width="1370" height="317.0" direction="ltr" style="max-width: none; height: 317.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Breaking</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">News:</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
# ...

# %% [markdown]
# ***5 Fake News***

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("Coronavirus Bioweapon – How China Stole Coronavirus From Canada And Weaponized It.")
displacy.render(doc, style="dep", jupyter=True,  options={'distance': 90})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="2441ed66352a48e6adfa0141d4e557bf-0" class="displacy" width="1040" height="362.0" direction="ltr" style="max-width: none; height: 362.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Coronavirus</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">Bioweapon –</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
# ...

# %%
nlp = spacy.load("en_core_web_sm")
text = "Coronavirus Bioweapon – How China Stole Coronavirus From Canada And Weaponized It."
doc = nlp(text)
sentence_spans = list(doc.sents)
displacy.render(sentence_spans, style="dep", jupyter=True,  options={'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="fd2a5cfa52744e4ebef70554edf59c59-0" class="displacy" width="1370" height="437.0" direction="ltr" style="max-width: none; height: 437.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Coronavirus</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">Bioweapon –</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
# ...

# %% [markdown]
# ***6 Fake News***

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("Evidence Surfaces That The FBI Planned And Executed January 6 Capitol Riot")
displacy.render(doc, style="dep", jupyter=True,  options={'distance': 90})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="84f1c03e5cbf413fb1cd2764369a5f38-0" class="displacy" width="1130" height="362.0" direction="ltr" style="max-width: none; height: 362.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Evidence</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">Surfaces</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
# ...

# %%
nlp = spacy.load("en_core_web_sm")
text = "Evidence Surfaces That The FBI Planned And Executed January 6 Capitol Riot"
doc = nlp(text)
sentence_spans = list(doc.sents)
displacy.render(sentence_spans, style="dep", jupyter=True,  options={'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="efc6348b1d16418da6eea8def98b2950-0" class="displacy" width="1490" height="437.0" direction="ltr" style="max-width: none; height: 437.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Evidence</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">Surfaces</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
# ...

# %% [markdown]
# ***7 Fake News***

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("FBI agent suspected in Hillary email leaks found dead in apartment in murder-suicide")
displacy.render(doc, style="dep", jupyter=True,  options={'distance': 90})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="ba3eb5da51314d0eaae73a626dab45ad-0" class="displacy" width="1310" height="317.0" direction="ltr" style="max-width: none; height: 317.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">FBI</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">agent</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
# ...

# %%
nlp = spacy.load("en_core_web_sm")
text = "FBI agent suspected in Hillary email leaks found dead in apartment in murder-suicide"
doc = nlp(text)
sentence_spans = list(doc.sents)
displacy.render(sentence_spans, style="dep", jupyter=True,  options={'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="1594dd4f15c54209ae0ee68a238093b9-0" class="displacy" width="1730" height="377.0" direction="ltr" style="max-width: none; height: 377.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">FBI</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">agent</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
# ...

# %% [markdown]
# ***8 Fake News***

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("Our house is burning. Literally. The Amazon rain forest - the lungs which produces 20% of our planet’s oxygen - is on fire. It is an international crisis.")
displacy.render(doc, style="dep", jupyter=True,  options={'distance': 90})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="4fb00ce7d4a34eb298121c6f7c5a217b-0" class="displacy" width="2480" height="362.0" direction="ltr" style="max-width: none; height: 362.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Our</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">house</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
# ...

# %%
nlp = spacy.load("en_core_web_sm")
text = "Our house is burning. Literally. The Amazon rain forest - the lungs which produces 20% of our planet’s oxygen - is on fire. It is an international crisis."
doc = nlp(text)
sentence_spans = list(doc.sents)
displacy.render(sentence_spans, style="dep", jupyter=True,  options={'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="faa2d65f7e2745da8147c0fe35800bdc-0" class="displacy" width="530" height="257.0" direction="ltr" style="max-width: none; height: 257.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Our</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">house</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
# ...

# %% [markdown]
# ***9 Fake News***

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("Israeli Defense Minister: If Pakistan sends ground troops into Syria on any pretext, we will destroy this country with a nuclear attack")
displacy.render(doc, style="dep", jupyter=True,  options={'distance': 90})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="e9b465920b224a829cf1bebb95a55b17-0" class="displacy" width="2030" height="407.0" direction="ltr" style="max-width: none; height: 407.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Israeli</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">Defense</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
# ...

# %%
nlp = spacy.load("en_core_web_sm")
text = "Israeli Defense Minister: If Pakistan sends ground troops into Syria on any pretext, we will destroy this country with a nuclear attack"
doc = nlp(text)
sentence_spans = list(doc.sents)
displacy.render(sentence_spans, style="dep", jupyter=True,  options={'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="beb8d7eb1b5c4634b71969f85b6967cc-0" class="displacy" width="2690" height="497.0" direction="ltr" style="max-width: none; height: 497.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Israeli</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">Defense</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
# ...

# %% [markdown]
# ***10 Fake News***

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("Obama Signs Executive Order Banning The Pledge Of Allegiance In Schools Nationwide")
displacy.render(doc, style="dep", jupyter=True,  options={'distance': 90})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="e1c9320be4b0419d9437ae41dca4d62e-0" class="displacy" width="1130" height="362.0" direction="ltr" style="max-width: none; height: 362.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Obama</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">Signs</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
# ...

# %%
nlp = spacy.load("en_core_web_sm")
text = "Obama Signs Executive Order Banning The Pledge Of Allegiance In Schools Nationwide"
doc = nlp(text)
sentence_spans = list(doc.sents)
displacy.render(sentence_spans, style="dep", jupyter=True,  options={'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="e5adcea6c11242c08743019c776affdd-0" class="displacy" width="1490" height="437.0" direction="ltr" style="max-width: none; height: 437.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Obama</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">Signs</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
# ...

# %% [markdown]
# ***11 Fake News***

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("Bill and Hillary Clinton were reported to be using a Pizza restaurant as a front for a pedophile sex ring")
displacy.render(doc, style="dep", jupyter=True,  options={'distance': 90})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="b408a62dd9af45dcb4f6f6cb97b48c9c-0" class="displacy" width="1850" height="362.0" direction="ltr" style="max-width: none; height: 362.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Bill</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
# ...

# %%
nlp = spacy.load("en_core_web_sm")
text = "Bill and Hillary Clinton were reported to be using a Pizza restaurant as a front for a pedophile sex ring"
doc = nlp(text)
sentence_spans = list(doc.sents)
displacy.render(sentence_spans, style="dep", jupyter=True,  options={'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="f09d075192444dbbbfc3fe7f8ef0a5d5-0" class="displacy" width="2450" height="437.0" direction="ltr" style="max-width: none; height: 437.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Bill</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
# ...

# %% [markdown]
# ***12 Fake News***

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("Rupaul claims Trump touched him inappropriately in the 1990s")
displacy.render(doc, style="dep", jupyter=True,  options={'distance': 90})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="3a13bb31452041128dbd4e36665a9e90-0" class="displacy" width="860" height="272.0" direction="ltr" style="max-width: none; height: 272.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Rupaul</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">claims</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
# ...

# %%
nlp = spacy.load("en_core_web_sm")
text = "Rupaul claims Trump touched him inappropriately in the 1990s"
doc = nlp(text)
sentence_spans = list(doc.sents)
displacy.render(sentence_spans, style="dep", jupyter=True,  options={'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="64a7e4b9953e431aa127905d8f9ab39e-0" class="displacy" width="1130" height="317.0" direction="ltr" style="max-width: none; height: 317.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Rupaul</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">claims</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
# ...

# %% [markdown]
# ***13 Fake News***

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("A Trump supporter wearing a Trump/Pence t-shirt let it fly on a reporter from MSNBC because of his one sided reporting and the demonizing of Trump. This is one brave woman!  interesting day")
displacy.render(doc, style="dep", jupyter=True,  options={'distance': 90})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="86ed88cedaf443228b71f3490d3d3bcc-0" class="displacy" width="3290" height="452.0" direction="ltr" style="max-width: none; height: 452.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="362.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">A</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="362.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">Trump</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="362.0">
# ...

# %%
nlp = spacy.load("en_core_web_sm")
text = "A Trump supporter wearing a Trump/Pence t-shirt let it fly on a reporter from MSNBC because of his one sided reporting and the demonizing of Trump. This is one brave woman!  interesting day"
doc = nlp(text)
sentence_spans = list(doc.sents)
displacy.render(sentence_spans, style="dep", jupyter=True,  options={'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="37e870b0f12c42ffba23ee9490052a77-0" class="displacy" width="3410" height="557.0" direction="ltr" style="max-width: none; height: 557.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">A</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">Trump</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
# ...

# %% [markdown]
# ***14 Fake News***

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("Yoko Ono: I Had An Affair With Hillary Clinton In The 70's")
displacy.render(doc, style="dep", jupyter=True,  options={'distance': 90})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="5587ea2d717f44c596e390a7e0009e07-0" class="displacy" width="1220" height="272.0" direction="ltr" style="max-width: none; height: 272.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Yoko</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">Ono:</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
# ...

# %%
nlp = spacy.load("en_core_web_sm")
text = "Yoko Ono: I Had An Affair With Hillary Clinton In The 70's"
doc = nlp(text)
sentence_spans = list(doc.sents)
displacy.render(sentence_spans, style="dep", jupyter=True,  options={'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="d4395b59533443899348be915fc2630f-0" class="displacy" width="1130" height="257.0" direction="ltr" style="max-width: none; height: 257.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Yoko</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">Ono:</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
# ...

# %% [markdown]
# ***15 Fake News***

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("Trump’s grandfather was a pimp and tax evader; his father a member of the KKK")
displacy.render(doc, style="dep", jupyter=True,  options={'distance': 90})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="5d4cff2de24f4fcc9ca38769a01319a0-0" class="displacy" width="1490" height="407.0" direction="ltr" style="max-width: none; height: 407.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Trump</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">’s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
# ...

# %%
nlp = spacy.load("en_core_web_sm")
text = "Trump’s grandfather was a pimp and tax evader; his father a member of the KKK"
doc = nlp(text)
sentence_spans = list(doc.sents)
displacy.render(sentence_spans, style="dep", jupyter=True,  options={'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="3097868ff22e4ed29f1c1e79613a44e6-0" class="displacy" width="1970" height="497.0" direction="ltr" style="max-width: none; height: 497.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Trump</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">’s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
# ...

# %% [markdown]
# ***16 Fake News***

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("IT'S OVER: Hillary's ISIS Email Just Leaked & It's Worse than Anyone Could Have Imagined")
displacy.render(doc, style="dep", jupyter=True,  options={'distance': 90})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="71cf624c8bc3452489342e7b7bf224b9-0" class="displacy" width="1580" height="362.0" direction="ltr" style="max-width: none; height: 362.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">IT</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">'S</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
# ...

# %%
nlp = spacy.load("en_core_web_sm")
text = "IT'S OVER: Hillary's ISIS Email Just Leaked & It's Worse than Anyone Could Have Imagined"
doc = nlp(text)
sentence_spans = list(doc.sents)
displacy.render(sentence_spans, style="dep", jupyter=True,  options={'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="4fa5a1beb3c1470abfb49ff79c93ef60-0" class="displacy" width="410" height="197.0" direction="ltr" style="max-width: none; height: 197.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="107.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">IT</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="107.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">'S</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="107.0">
# ...

# %% [markdown]
# ***17 Fake News***

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("Trump offering freeone-way tickets to Africa & Mexico for those who wanna leave America")
displacy.render(doc, style="dep", jupyter=True,  options={'distance': 90})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="1d4ffdb3cc8244c19942f6ff57e6eb5b-0" class="displacy" width="1310" height="407.0" direction="ltr" style="max-width: none; height: 407.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Trump</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">offering</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
# ...

# %%
nlp = spacy.load("en_core_web_sm")
text = "Trump offering freeone-way tickets to Africa & Mexico for those who wanna leave America"
doc = nlp(text)
sentence_spans = list(doc.sents)
displacy.render(sentence_spans, style="dep", jupyter=True,  options={'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="2dcf5860c1ab413bb97445c560024b7a-0" class="displacy" width="1730" height="497.0" direction="ltr" style="max-width: none; height: 497.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Trump</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">offering</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
# ...

# %% [markdown]
# ***18 Fake News***

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("SURGEONS ADMIT THAT MAMMOGRAPHY IS OUTDATED AND HARMFUL TO WOMEN")
displacy.render(doc, style="dep", jupyter=True,  options={'distance': 90})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="4942cb364b694c09847d8f9806710dd0-0" class="displacy" width="950" height="272.0" direction="ltr" style="max-width: none; height: 272.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">SURGEONS</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">ADMIT</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
# ...

# %%
nlp = spacy.load("en_core_web_sm")
text = "SURGEONS ADMIT THAT MAMMOGRAPHY IS OUTDATED AND HARMFUL TO WOMEN"
doc = nlp(text)
sentence_spans = list(doc.sents)
displacy.render(sentence_spans, style="dep", jupyter=True,  options={'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="9d6e9a56151942c78267283c0cf5472a-0" class="displacy" width="1250" height="317.0" direction="ltr" style="max-width: none; height: 317.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">SURGEONS</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">ADMIT</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
# ...

# %% [markdown]
# ***19 Fake News***

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("HOMEOPATHIC TREATMENT OF CORONAVIRUS")
displacy.render(doc, style="dep", jupyter=True,  options={'distance': 90})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="59bff1e5377843e7b23048dab5893d88-0" class="displacy" width="410" height="182.0" direction="ltr" style="max-width: none; height: 182.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="92.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">HOMEOPATHIC</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="92.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">TREATMENT</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="92.0">
# ...

# %%
nlp = spacy.load("en_core_web_sm")
text = "HOMEOPATHIC TREATMENT OF CORONAVIRUS"
doc = nlp(text)
sentence_spans = list(doc.sents)
displacy.render(sentence_spans, style="dep", jupyter=True,  options={'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="3ca6dfbd50384529b6dbb48fdd48ff52-0" class="displacy" width="530" height="197.0" direction="ltr" style="max-width: none; height: 197.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="107.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">HOMEOPATHIC</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="107.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">TREATMENT</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="107.0">
# ...

# %% [markdown]
# ***20 Fake News***

# %% [markdown]
# # SpaCy Named Entities
#
# "A named entity is a “real-world object” that’s assigned a name – for example, a person, a country, a product or a book title. spaCy can recognize various types of named entities in a document, by asking the model for a prediction. Because models are statistical and strongly depend on the examples they were trained on, this doesn’t always work perfectly and might need some tuning later, depending on your use case."

# %% [markdown]
# 1 Fake

# %%
text = "Donald Trump sent his own plane to transport 200 stranded marines"

nlp = spacy.load("en_core_web_sm")
doc = nlp(text)

# Named entities are available as the ents property of a Doc
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Donald Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  sent his own plane to transport
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     200
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  stranded marines</div></span>

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("Donald Trump sent his own plane to transport 200 stranded marines")

for token in doc:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
            token.shape_, token.is_alpha, token.is_stop)

displacy.render(doc, jupyter=True,  options={'distance': 70})

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("Donald Trump sent his own plane to transport 200 stranded marines")

# document level
ents = [(e.text, e.start_char, e.end_char, e.label_) for e in doc.ents]
print(ents)

# token level
ent_san = [doc[0].text, doc[0].ent_iob_, doc[0].ent_type_]
ent_francisco = [doc[1].text, doc[1].ent_iob_, doc[1].ent_type_]
print(ent_san)  # ['San', 'B', 'GPE']
print(ent_francisco)  # ['Francisco', 'I', 'GPE']

displacy.render(doc, style="ent", jupyter=True)
# Out:
# [('Donald Trump', 0, 12, 'PERSON'), ('200', 45, 48, 'CARDINAL')]
# ['Donald', 'B', 'PERSON']
# ['Trump', 'I', 'PERSON']
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Donald Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  sent his own plane to transport
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     200
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  stranded marines</div></span>

# %% [markdown]
# 2 Fake

# %%
text = "FBI director received millions from Clinton Foundation, his brother’s law firm does Clinton’s taxes"

nlp = spacy.load("en_core_web_sm")
doc = nlp(text)

# Named entities are available as the ents property of a Doc
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     FBI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  director received
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     millions
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  from
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Clinton Foundation
# ...

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("FBI director received millions from Clinton Foundation, his brother’s law firm does Clinton’s taxes")

for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
    
    
displacy.render(doc, style="ent", jupyter=True,  options={'distance': 70})
# Out:
# FBI 0 3 ORG
# millions 22 30 CARDINAL
# Clinton Foundation 36 54 ORG
# Clinton 84 91 ORG
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     FBI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  director received
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     millions
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  from
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Clinton Foundation
# ...

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("FBI director received millions from Clinton Foundation, his brother’s law firm does Clinton’s taxes")

# document level
ents = [(e.text, e.start_char, e.end_char, e.label_) for e in doc.ents]
print(ents)

# token level
ent_san = [doc[0].text, doc[0].ent_iob_, doc[0].ent_type_]
ent_francisco = [doc[1].text, doc[1].ent_iob_, doc[1].ent_type_]
print(ent_san)  # ['San', 'B', 'GPE']
print(ent_francisco)  # ['Francisco', 'I', 'GPE']

displacy.render(doc, style="ent", jupyter=True)
# Out:
# [('FBI', 0, 3, 'ORG'), ('millions', 22, 30, 'CARDINAL'), ('Clinton Foundation', 36, 54, 'ORG'), ('Clinton', 84, 91, 'ORG')]
# ['FBI', 'B', 'ORG']
# ['director', 'O', '']
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     FBI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  director received
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     millions
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  from
# ...

# %% [markdown]
# # Examining the Fake News for Insights

# %% [markdown]
# # SpaCy Sentiment Analysis

# %% [markdown]
# # Fake News Data
#
# Donald Trump sent his own plane to transport 200 stranded marines.
#
# FBI director received millions from Clinton Foundation, his brother’s law firm does Clinton’s taxes.
#
# Pope Francis shocks world, endorses Donald Trump for president, Releases Statement.
#
# Breaking News: China will admit coronavirus coming from its P4 Lab.
#
# Coronavirus Bioweapon – How China Stole Coronavirus From Canada And Weaponized It.
#
# Evidence Surfaces That The FBI Planned And Executed January 6 Capitol Riot.
#
# FBI agent suspected in Hillary email leaks found dead in apartment in murder-suicide.
#
# Our house is burning. Literally. The Amazon rain forest - the lungs which produces 20% of our planet’s oxygen - is on fire. It is an international crisis. Members of the G7 Summit, let's discuss this emergency first order in two days!
#
# Israeli Defense Minister: If Pakistan sends ground troops into Syria on any pretext, we will destroy this country with a nuclear attack.
#
# Obama Signs Executive Order Banning The Pledge Of Allegiance In Schools Nationwide.
#
# Bill and Hillary Clinton were reported to be using a Pizza restaurant as a front for a pedophile sex ring.
#
# Rupaul claims Trump touched him inappropriately in the 1990s.
#
# A Trump supporter wearing a Trump/Pence t-shirt let it fly on a reporter from MSNBC because of his one sided reporting and the demonizing of Trump. This is one brave woman!  interesting day.
#
# Yoko Ono: "I Had An Affair With Hillary Clinton In The 70's"
#
# “Trump’s grandfather was a pimp and tax evader; his father a member of the KKK”.
#
# IT'S OVER: Hillary's ISIS Email Just Leaked & It's Worse than Anyone Could Have Imagined.
#
# Trump offering freeone-way tickets to Africa & Mexico for those who wanna leave America.
#
# SURGEONS ADMIT THAT MAMMOGRAPHY IS OUTDATED AND HARMFUL TO WOMEN.
#
# HOMEOPATHIC TREATMENT OF CORONAVIRUS.
#
# Lottery-winning woman arrested for relieving herself on her boss’s desk.

# %%
from textblob import TextBlob
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('brown')

# %%
review = TextBlob("Donald Trump sent his own plane to transport 200 stranded marines")

# %%
review.tags
# Out:
# [('Donald', 'NNP'),
#  ('Trump', 'NNP'),
#  ('sent', 'VBD'),
#  ('his', 'PRP$'),
#  ('own', 'JJ'),
#  ('plane', 'NN'),
#  ('to', 'TO'),
#  ('transport', 'VB'),
#  ('200', 'CD'),
#  ('stranded', 'JJ'),
#  ('marines', 'NNS')]

# %%
review.noun_phrases
# Out:
# WordList(['donald trump', 'own plane'])

# %% [markdown]
# # TEST on testimonial  (fake news)

# %%
testimonial = TextBlob("Donald Trump sent his own plane to transport 200 stranded marines")

# %%
testimonial.sentiment
# Out:
# Sentiment(polarity=0.6, subjectivity=1.0)

# %% [markdown]
# #Sentiment of all twenty Fake News Combined

# %%
user_reviews = TextBlob("Donald Trump sent his own plane to transport 200 stranded marines. \
   FBI director received millions from Clinton Foundation, his brother’s law firm does Clintons taxes. \
           Pope Francis shocks world, endorses Donald Trump for president, Releases Statement. \
                           Breaking News: China will admit coronavirus coming from its P4 Lab. \
                                                  Coronavirus Bioweapon – How China Stole Coronavirus From Canada And Weaponized It. \
                                                                                Evidence Surfaces That The FBI Planned And Executed January 6 Capitol Riot. \
                                                                                                                     FBI agent suspected in Hillary email leaks found dead in apartment in murder-suicide. \
                                                                                                                                                                 Our house is burning, Literally, The Amazon rain forest - the lungs which produces 20% of our planet’s oxygen - is on fire. It is an international crisis. Members of the G7 Summit, let's discuss this emergency first order in two days! \
                                                                                                                                                                           Israeli Defense Minister: If Pakistan sends ground troops into Syria on any pretext, we will destroy this country with a nuclear attack. \
                                                          Obama Signs Executive Order Banning The Pledge Of Allegiance In Schools Nationwide. \
       Bill and Hillary Clinton were reported to be using a Pizza restaurant as a front for a pedophile sex ring. \
                Rupaul claims Trump touched him inappropriately in the 1990s. \
                       A Trump supporter wearing a Trump/Pence t-shirt let it fly on a reporter from MSNBC because of his one sided reporting and the demonizing of Trump. This is one brave woman!  interesting day. \
                              Yoko Ono: I Had An Affair With Hillary Clinton In The 70's. \
                                     Trump’s grandfather was a pimp and tax evader; his father a member of the KKK. \
                                            IT'S OVER: Hillary's ISIS Email Just Leaked & It's Worse than Anyone Could Have Imagined. \
                                                   Trump offering freeone-way tickets to Africa & Mexico for those who wanna leave America. \
                                                          SURGEONS ADMIT THAT MAMMOGRAPHY IS OUTDATED AND HARMFUL TO WOMEN. \
                                                                 HOMEOPATHIC TREATMENT OF CORONAVIRUS. \
                                                                        Lottery-winning woman arrested for relieving herself on her boss’s desk")
user_reviews.words

user_reviews.sentences
# Out:
# [Sentence("Donald Trump sent his own plane to transport 200 stranded marines."),
#  Sentence("FBI director received millions from Clinton Foundation, his brother’s law firm does Clintons taxes."),
#  Sentence("Pope Francis shocks world, endorses Donald Trump for president, Releases Statement."),
#  Sentence("Breaking News: China will admit coronavirus coming from its P4 Lab."),
#  Sentence("Coronavirus Bioweapon – How China Stole Coronavirus From Canada And Weaponized It."),
#  Sentence("Evidence Surfaces That The FBI Planned And Executed January 6 Capitol Riot."),
#  Sentence("FBI agent suspected in Hillary email leaks found dead in apartment in murder-suicide."),
#  Sentence("Our house is burning, Literally, The Amazon rain forest - the lungs which produces 20% of our planet’s oxygen - is on fire."),
#  Sentence("It is an international crisis."),
#  Sentence("Members of the G7 Summit, let's discuss this emergency first order in two days!"),
# ...

# %%
for sentence in user_reviews.sentences:
    print(sentence.sentiment)
# Out:
# Sentiment(polarity=0.6, subjectivity=1.0)
# Sentiment(polarity=-0.2, subjectivity=0.4)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.2, subjectivity=0.4)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.3125, subjectivity=0.3333333333333333)
# Sentiment(polarity=-0.2, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.8, subjectivity=0.9)
# Sentiment(polarity=1.0, subjectivity=1.0)
# Sentiment(polarity=0.5, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.4, subjectivity=0.6)
# Sentiment(polarity=0.0, subjectivity=0.0)
# ...

# %%
from spacytextblob.spacytextblob import SpacyTextBlob

nlp = spacy.load('en_core_web_sm')
nlp.add_pipe('spacytextblob')
text = "'Donald Trump sent his own plane to transport 200 stranded marines.'"
doc = nlp(text)

# %% [markdown]
# Return a tuple of form (polarity, subjectivity ) where polarity is a float within the range [-1.0, 1.0] and subjectivity is a float within the range [0.0, 1.0] where 0.0 is very objective and 1.0 is very subjective.

# %%
print('Polarity {}'.format(doc._.polarity))
# Out:
# Polarity 0.6

# %%
print('Subjectivity {}'.format(doc._.subjectivity))
# Out:
# Subjectivity 1.0

# %%
print('Assessments {}'.format(doc._.assessments))
# Out:
# Assessments [(['own'], 0.6, 1.0, None)]

# %%
first_user = nlp("Donald Trump sent his own plane to transport 200 stranded marines.")
second_user = nlp("HOMEOPATHIC TREATMENT OF CORONAVIRUS.")

# Similarity of two documents
print(first_user, "<->", second_user, first_user.similarity(second_user))
# Out:
# Donald Trump sent his own plane to transport 200 stranded marines. <-> HOMEOPATHIC TREATMENT OF CORONAVIRUS. 0.3333593714170131
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   """

# %% [markdown]
# # End of NLP with SpaCy
