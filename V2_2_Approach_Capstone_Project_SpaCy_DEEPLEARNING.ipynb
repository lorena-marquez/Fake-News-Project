# %% [markdown]
# <a href="https://colab.research.google.com/github/lorena-marquez/Fake-News-Project/blob/main/V2_2_Approach_Capstone_Project_SpaCy_DEEPLEARNING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MBA509 Lesson#7 Applications of Deep Learning
#
# This notebook explores:
# * how NLP (SpaCy) are applied to gain insights from documents (unstructured data).
# * How to build Neural Networks: simpleRNN, RNN, LSTMS, CNNs
# * How to apply Convolutional Neural Networks to Detect Actions in Video Advertising
#
# The material also includes a section on how to construct our own AI  using Tensorflow & Keras APIs

# %% [markdown]
# # Natural Language Processing
#
# We will use SpaCy: https://spacy.io/
#
# Primary Tasks:
# * Document Insights: structures, words, similarities, polarities
# * Named Entity Recognition
# * Sentiment Analysis

# %% [markdown]
# # INSTALLATIONS

# %%
# !pip install spacy

# %%
# !pip install SpacyTextBlob

# %%
# !python -m spacy download en_core_web_sm

# %%
import spacy
from spacy import displacy
from IPython.core.display import display, HTML
from spacy.tokens import Span
from spacy.symbols import ORTH
from spacy.lang.en import English

# %% [markdown]
# # SpaCy NLP Process
#
# "This will return a Language object containing all components and data needed to process text. We usually call it nlp. Calling the nlp object on a string of text will return a processed Doc:"

# %% [markdown]
# # The Editorial Data for L'Interdit (translate: The Forbidden) Fragrance

# %% [markdown]
# L'Interdit Eau de Parfum by Givenchy is a Amber Floral fragrance for women. This is a new fragrance. L'Interdit Eau de Parfum was launched in 2018. L'Interdit Eau de Parfum was created by Dominique Ropion, Anne Flipo and Fanny Bal. Top notes are Pear and Bergamot; middle notes are Tuberose, Orange Blossom and Jasmine Sambac; base notes are Patchouli, Vanilla, Ambroxan and Vetiver.

# %% [markdown]
# Among the first perfume creations of the house of Givenchy stands the legendary scent of L'Interdit from 1957, dedicated to actress Audrey Hepburn as the most significant muse of this fashion designer.
#
# In 2018, its new, modern version called L'Interdit Givenchy comes out, developed by perfumers Dominique Ropion, Anne Flipo and Fanny Bal as a floral-woody composition. The perfume is built on the basis of contrast between a bouquet of white flowers (including jasmine, tuberose and orange blossom) and intense woody and earthy notes of patchouli and vetiver. The concept behind the creation is the "thrill of the forbidden" and the challenge of crossing the line.
#
# ACTIVE INGREDIENTS:
#
# "A white floral exalted with a dark accord. The first resolutely underground flower.
# The white notes - orange blossom, jasmin and tuberose - are interlaced with darker more mysterious notes of vetiver and patchouli.
# A generous intense brightness that isn’t afraid of subversion.
# Unforgettable, intense, addictive and fearlessly elegant. The shocking side of chic."
#
# The bottle of thick glass pays homage to the original shape with a more modern outline with the 4 G logo added to the black ribbon that encircles the neck. The face of the new L'Interdit release is actress Rooney Mara. Givenchy L'Interdit is available in 35, 50 and 80 ml Eau de Parfum.

# %% [markdown]
# # The Grammatical Structure - 4 Fake News x 4 True News
#
# *  How are the words related?
#
# "For example, if you’re analyzing text, it makes a huge difference whether a noun is the subject of a sentence, or the object – or whether “google” is used as a verb, or refers to the website or company in a specific context."

# %% [markdown]
# ***1 Fake News***

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("New research from Harvard University shows that the chemical in chilli peppers that causes the hot sensation in your mouth reduces the replication rate of coronaviruses. The researchers are currently investigating whether adding more spicy foods to your diet coul dhelp combat COVID-19.")
displacy.render(doc, style="dep", jupyter=True,  options={'distance': 90})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="563bc693eb874339aa7b5c198f8fbe6c-0" class="displacy" width="3920" height="452.0" direction="ltr" style="max-width: none; height: 452.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="362.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">New</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="362.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">research</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="362.0">
# ...

# %%
nlp = spacy.load("en_core_web_sm")
text = "New research from Harvard University shows that the chemical in chilli peppers that causes the hot sensation in your mouth reduces the replication rate of coronaviruses. The researchers are currently investigating whether adding more spicy foods to your diet coul dhelp combat COVID-19."
doc = nlp(text)
sentence_spans = list(doc.sents)
displacy.render(sentence_spans, style="dep", jupyter=True,  options={'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="98ad3fe6fe4b48ef85cb19be223fda2f-0" class="displacy" width="3170" height="497.0" direction="ltr" style="max-width: none; height: 497.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">New</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">research</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
# ...

# %% [markdown]
# ***2 Fake News***

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("A study conducted in University College London found that those who drank more than 3 cups of coffee per day were less likely to suffer from severe Coronavirus symptoms.Researchers said they were conducting follow-up studies to better understand the links between caffeine and the immune system.")
displacy.render(doc, style="dep", jupyter=True,  options={'distance': 90})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="dcf2192dbe8a4ede8f45084823e86762-0" class="displacy" width="4370" height="497.0" direction="ltr" style="max-width: none; height: 497.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">A</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">study</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
# ...

# %%
nlp = spacy.load("en_core_web_sm")
text = "A study conducted in University College London found that those who drank more than 3 cups of coffee per day were less likely to suffer from severe Coronavirus symptoms.Researchers said they were conducting follow-up studies to better understand the links between caffeine and the immune system."
doc = nlp(text)
sentence_spans = list(doc.sents)
displacy.render(sentence_spans, style="dep", jupyter=True,  options={'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="a536897e661e4ea781b7d7f19369608e-0" class="displacy" width="3530" height="617.0" direction="ltr" style="max-width: none; height: 617.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">A</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">study</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
# ...

# %% [markdown]
# ***3 Fake News***

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("A whistleblower report from a leading pharmaceutical company was leaked to the Guardian newspaper in April. The report stated that the coronavirus vaccine being developed by the company causes a high rate of complications, but that these concerns were being disregarded in favour of releasing the vaccine quickly.")
displacy.render(doc, style="dep", jupyter=True,  options={'distance': 90})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="b94b27295b0f460983f0432e5aef81cf-0" class="displacy" width="4370" height="587.0" direction="ltr" style="max-width: none; height: 587.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">A</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">whistleblower</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
# ...

# %%
nlp = spacy.load("en_core_web_sm")
text = "A whistleblower report from a leading pharmaceutical company was leaked to the Guardian newspaper in April. The report stated that the coronavirus vaccine being developed by the company causes a high rate of complications, but that these concerns were being disregarded in favour of releasing the vaccine quickly."
doc = nlp(text)
sentence_spans = list(doc.sents)
displacy.render(sentence_spans, style="dep", jupyter=True,  options={'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="152f0e966355415eaa024f7a5b054c33-0" class="displacy" width="1970" height="497.0" direction="ltr" style="max-width: none; height: 497.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">A</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">whistleblower</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
# ...

# %% [markdown]
# ***4 Fake News***

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("The programming team who designed the HSE app to support coronavirus contact-tracing were found to have previously worked with Cambridge Analytica, raising concerns about citizen’s data privacy. The app is designed to monitor people’s movements in order to support the government’s contact tracing initiative.")
displacy.render(doc, style="dep", jupyter=True,  options={'distance': 90})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="a164cba1215146a9920826148b1f8919-0" class="displacy" width="4370" height="452.0" direction="ltr" style="max-width: none; height: 452.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="362.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="362.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">programming</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="362.0">
# ...

# %%
nlp = spacy.load("en_core_web_sm")
text = "The programming team who designed the HSE app to support coronavirus contact-tracing were found to have previously worked with Cambridge Analytica, raising concerns about citizen’s data privacy. The app is designed to monitor people’s movements in order to support the government’s contact tracing initiative."
doc = nlp(text)
sentence_spans = list(doc.sents)
displacy.render(sentence_spans, style="dep", jupyter=True,  options={'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="65f9073e73274a36bc617a4cb63690db-0" class="displacy" width="3530" height="497.0" direction="ltr" style="max-width: none; height: 497.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">programming</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
# ...

# %% [markdown]
# ***1 True News***

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("A new study from Trinity College Dublin revealed that vitamin D is likely to reduce serious coronavirus complications. The researchers urged the government to advise Irish citizens to take daily vitamin D supplements.")
displacy.render(doc, style="dep", jupyter=True,  options={'distance': 90})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="58aa2eb9aab44998b8e6486a24949ecb-0" class="displacy" width="3020" height="362.0" direction="ltr" style="max-width: none; height: 362.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">A</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">new</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
# ...

# %%
nlp = spacy.load("en_core_web_sm")
text = "A new study from Trinity College Dublin revealed that vitamin D is likely to reduce serious coronavirus complications. The researchers urged the government to advise Irish citizens to take daily vitamin D supplements."
doc = nlp(text)
sentence_spans = list(doc.sents)
displacy.render(sentence_spans, style="dep", jupyter=True,  options={'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="6e47e57c89204c92a97ce72b37f12d30-0" class="displacy" width="2210" height="437.0" direction="ltr" style="max-width: none; height: 437.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">A</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">new</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
# ...

# %% [markdown]
# ***2 True News***

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("Mixed-martial arts fighter Conor McGregor posted an online video urging the Irish government to enforce a complete lockdown, with the help of the army. I urge our government to utilise our defence forces he stated")
displacy.render(doc, style="dep", jupyter=True,  options={'distance': 90})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="31760d2b5acf444b87ddc286287ef17c-0" class="displacy" width="3290" height="452.0" direction="ltr" style="max-width: none; height: 452.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="362.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Mixed-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="362.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">martial</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="362.0">
# ...

# %%
nlp = spacy.load("en_core_web_sm")
text = "Mixed-martial arts fighter Conor McGregor posted an online video urging the Irish government to enforce a complete lockdown, with the help of the army. I urge our government to utilise our defence forces he stated"
doc = nlp(text)
sentence_spans = list(doc.sents)
displacy.render(sentence_spans, style="dep", jupyter=True,  options={'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="55ab385ebbb54dfd9605283909a84820-0" class="displacy" width="3050" height="437.0" direction="ltr" style="max-width: none; height: 437.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Mixed-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">martial</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
# ...

# %% [markdown]
# ***3 True News***

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("Sinn Féin President Mary Lou McDonald called off two Sinn Féin rallies in March, after a case of coronavirus was reported at her children's school")
displacy.render(doc, style="dep", jupyter=True,  options={'distance': 90})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="157f0e3852a84050a9230945a302d30c-0" class="displacy" width="2390" height="497.0" direction="ltr" style="max-width: none; height: 497.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Sinn</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">Féin</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
# ...

# %%
nlp = spacy.load("en_core_web_sm")
text = "Sinn Féin President Mary Lou McDonald called off two Sinn Féin rallies in March, after a case of coronavirus was reported at her children's school"
doc = nlp(text)
sentence_spans = list(doc.sents)
displacy.render(sentence_spans, style="dep", jupyter=True,  options={'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="8fe525a1a51a4b8faa0dbc50416b3d59-0" class="displacy" width="3170" height="617.0" direction="ltr" style="max-width: none; height: 617.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Sinn</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">Féin</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
# ...

# %% [markdown]
# ***4 True News***

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("As most of Europe is in lockdown, Sweden is pursuing a different strategy against COVID-19. Pubs, restaurants, gyms and most schools remain open in the Scandinavian state, with the government relying on personal responsibility for compliance rather than strict enforcement. Official guidance states that citizens may socialise, as long as they stay at arm’s length from each other.")
displacy.render(doc, style="dep", jupyter=True,  options={'distance': 90})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="f19b845d7b3344659f7978a3bd8860d6-0" class="displacy" width="5360" height="407.0" direction="ltr" style="max-width: none; height: 407.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">As</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">most</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
# ...

# %%
nlp = spacy.load("en_core_web_sm")
text = "As most of Europe is in lockdown, Sweden is pursuing a different strategy against COVID-19. Pubs, restaurants, gyms and most schools remain open in the Scandinavian state, with the government relying on personal responsibility for compliance rather than strict enforcement. Official guidance states that citizens may socialise, as long as they stay at arm’s length from each other."
doc = nlp(text)
sentence_spans = list(doc.sents)
displacy.render(sentence_spans, style="dep", jupyter=True,  options={'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="2e6d788bbb23402483e29809e3adeacb-0" class="displacy" width="1850" height="437.0" direction="ltr" style="max-width: none; height: 437.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">As</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">most</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
# ...

# %% [markdown]
# # SpaCy Named Entities - Fake News
#
# > Indented block
#
#
#
# "A named entity is a “real-world object” that’s assigned a name – for example, a person, a country, a product or a book title. spaCy can recognize various types of named entities in a document, by asking the model for a prediction. Because models are statistical and strongly depend on the examples they were trained on, this doesn’t always work perfectly and might need some tuning later, depending on your use case."

# %% [markdown]
# 1 Fake

# %%
text = "New research from Harvard University shows that the chemical in chilli peppers that causes the hot sensation in your mouth reduces the replication rate of coronaviruses. The researchers are currently investigating whether adding more spicy foods to your diet couldhelp combat COVID-19."

nlp = spacy.load("en_core_web_sm")
doc = nlp(text)

# Named entities are available as the ents property of a Doc
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">New research from
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Harvard University
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  shows that the chemical in chilli peppers that causes the hot sensation in your mouth reduces the replication rate of coronaviruses. The researchers are currently investigating whether adding more spicy foods to your diet couldhelp combat
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     COVID-19
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .</div></span>

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("New research from Harvard University shows that the chemical in chilli peppers that causes the hot sensation in your mouth reduces the replication rate of coronaviruses. The researchers are currently investigating whether adding more spicy foods to your diet coul dhelp combat COVID-19.")

for token in doc:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
            token.shape_, token.is_alpha, token.is_stop)

displacy.render(doc, jupyter=True,  options={'distance': 70})
# Out:
# New new ADJ JJ amod Xxx True False
# research research NOUN NN nsubj xxxx True False
# from from ADP IN prep xxxx True True
# Harvard Harvard PROPN NNP compound Xxxxx True False
# University University PROPN NNP pobj Xxxxx True False
# shows show VERB VBZ ROOT xxxx True False
# that that SCONJ IN mark xxxx True True
# the the DET DT det xxx True True
# chemical chemical NOUN NN ccomp xxxx True False
# in in ADP IN prep xx True True
# chilli chilli PROPN NNP compound xxxx True False
# peppers pepper NOUN NNS pobj xxxx True False
# that that PRON WDT nsubj xxxx True True
# causes cause VERB VBZ relcl xxxx True False
# the the DET DT det xxx True True
# hot hot ADJ JJ amod xxx True False
# sensation sensation NOUN NN dobj xxxx True False
# in in ADP IN prep xx True True
# your your PRON PRP$ poss xxxx True True
# mouth mouth NOUN NN pobj xxxx True False
# reduces reduce VERB VBZ ccomp xxxx True False
# the the DET DT det xxx True True
# ...

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("New research from Harvard University shows that the chemical in chilli peppers that causes the hot sensation in your mouth reduces the replication rate of coronaviruses. The researchers are currently investigating whether adding more spicy foods to your diet coul dhelp combat COVID-19.")

# document level
ents = [(e.text, e.start_char, e.end_char, e.label_) for e in doc.ents]
print(ents)

# token level
ent_san = [doc[0].text, doc[0].ent_iob_, doc[0].ent_type_]
ent_francisco = [doc[1].text, doc[1].ent_iob_, doc[1].ent_type_]
print(ent_san)  # ['San', 'B', 'GPE']
print(ent_francisco)  # ['Francisco', 'I', 'GPE']

displacy.render(doc, style="ent", jupyter=True)
# Out:
# [('Harvard University', 18, 36, 'ORG'), ('COVID-19', 277, 285, 'ORG')]
# ['New', 'O', '']
# ['research', 'O', '']
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">New research from
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Harvard University
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  shows that the chemical in chilli peppers that causes the hot sensation in your mouth reduces the replication rate of coronaviruses. The researchers are currently investigating whether adding more spicy foods to your diet coul dhelp combat
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     COVID-19
# ...

# %% [markdown]
# 2 Fake

# %%
text = "A study conducted in University College London found that those who drank more than 3 cups of coffee per day were less likely to suffer from severe Coronavirus symptoms.Researchers said they were conducting follow-up studies to better understand the links between caffeine and the immune system."

nlp = spacy.load("en_core_web_sm")
doc = nlp(text)

# Named entities are available as the ents property of a Doc
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">A study conducted in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     University College London
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  found that those who drank
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     more than 3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  cups of coffee per day were less likely to suffer from severe
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
# ...

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("A study conducted in University College London found that those who drank more than 3 cups of coffee per day were less likely to suffer from severe Coronavirus symptoms.Researchers said they were conducting follow-up studies to better understand the links between caffeine and the immune system.")

for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
    
    
displacy.render(doc, style="ent", jupyter=True,  options={'distance': 70})
# Out:
# University College London 21 46 ORG
# more than 3 74 85 CARDINAL
# Coronavirus 148 159 ORG
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">A study conducted in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     University College London
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  found that those who drank
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     more than 3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  cups of coffee per day were less likely to suffer from severe
# ...

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("A study conducted in University College London found that those who drank more than 3 cups of coffee per day were less likely to suffer from severe Coronavirus symptoms.Researchers said they were conducting follow-up studies to better understand the links between caffeine and the immune system.")

# document level
ents = [(e.text, e.start_char, e.end_char, e.label_) for e in doc.ents]
print(ents)

# token level
ent_san = [doc[0].text, doc[0].ent_iob_, doc[0].ent_type_]
ent_francisco = [doc[1].text, doc[1].ent_iob_, doc[1].ent_type_]
print(ent_san)  # ['San', 'B', 'GPE']
print(ent_francisco)  # ['Francisco', 'I', 'GPE']

displacy.render(doc, style="ent", jupyter=True)
# Out:
# [('University College London', 21, 46, 'ORG'), ('more than 3', 74, 85, 'CARDINAL'), ('Coronavirus', 148, 159, 'ORG')]
# ['A', 'O', '']
# ['study', 'O', '']
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">A study conducted in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     University College London
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  found that those who drank
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     more than 3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# ...

# %% [markdown]
# 3 Fake

# %%
text = "A whistleblower report from a leading pharmaceutical company was leaked to the Guardian newspaper in April. The report stated that the coronavirus vaccine being developed by the company causes a high rate of complications, but that these concerns were being disregarded in favour of releasing the vaccine quickly."

nlp = spacy.load("en_core_web_sm")
doc = nlp(text)

# Named entities are available as the ents property of a Doc
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">A whistleblower report from a leading pharmaceutical company was leaked to the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Guardian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  newspaper in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     April
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ...

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("A whistleblower report from a leading pharmaceutical company was leaked to the Guardian newspaper in April. The report stated that the coronavirus vaccine being developed by the company causes a high rate of complications, but that these concerns were being disregarded in favour of releasing the vaccine quickly.")

for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
    
    
displacy.render(doc, style="ent", jupyter=True,  options={'distance': 70})
# Out:
# Guardian 79 87 ORG
# April 101 106 DATE
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">A whistleblower report from a leading pharmaceutical company was leaked to the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Guardian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  newspaper in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     April
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ...

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("A whistleblower report from a leading pharmaceutical company was leaked to the Guardian newspaper in April. The report stated that the coronavirus vaccine being developed by the company causes a high rate of complications, but that these concerns were being disregarded in favour of releasing the vaccine quickly.")

# document level
ents = [(e.text, e.start_char, e.end_char, e.label_) for e in doc.ents]
print(ents)

# token level
ent_san = [doc[0].text, doc[0].ent_iob_, doc[0].ent_type_]
ent_francisco = [doc[1].text, doc[1].ent_iob_, doc[1].ent_type_]
print(ent_san)  # ['San', 'B', 'GPE']
print(ent_francisco)  # ['Francisco', 'I', 'GPE']

displacy.render(doc, style="ent", jupyter=True)
# Out:
# [('Guardian', 79, 87, 'ORG'), ('April', 101, 106, 'DATE')]
# ['A', 'O', '']
# ['whistleblower', 'O', '']
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">A whistleblower report from a leading pharmaceutical company was leaked to the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Guardian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  newspaper in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     April
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ...

# %% [markdown]
# 4 Fake

# %%
text = "The programming team who designed the HSE app to support coronavirus contact-tracing were found to have previously worked with Cambridge Analytica, raising concerns about citizen’s data privacy. The app is designed to monitor people’s movements in order to support the government’s contact tracing initiative."

nlp = spacy.load("en_core_web_sm")
doc = nlp(text)

# Named entities are available as the ents property of a Doc
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The programming team who designed the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     HSE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  app to support coronavirus contact-tracing were found to have previously worked with
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cambridge Analytica
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ...

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("The programming team who designed the HSE app to support coronavirus contact-tracing were found to have previously worked with Cambridge Analytica, raising concerns about citizen’s data privacy. The app is designed to monitor people’s movements in order to support the government’s contact tracing initiative.")

for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
    
    
displacy.render(doc, style="ent", jupyter=True,  options={'distance': 70})
# Out:
# HSE 38 41 ORG
# Cambridge Analytica 127 146 GPE
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The programming team who designed the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     HSE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  app to support coronavirus contact-tracing were found to have previously worked with
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cambridge Analytica
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ...

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("The programming team who designed the HSE app to support coronavirus contact-tracing were found to have previously worked with Cambridge Analytica, raising concerns about citizen’s data privacy. The app is designed to monitor people’s movements in order to support the government’s contact tracing initiative.")

# document level
ents = [(e.text, e.start_char, e.end_char, e.label_) for e in doc.ents]
print(ents)

# token level
ent_san = [doc[0].text, doc[0].ent_iob_, doc[0].ent_type_]
ent_francisco = [doc[1].text, doc[1].ent_iob_, doc[1].ent_type_]
print(ent_san)  # ['San', 'B', 'GPE']
print(ent_francisco)  # ['Francisco', 'I', 'GPE']

displacy.render(doc, style="ent", jupyter=True)
# Out:
# [('HSE', 38, 41, 'ORG'), ('Cambridge Analytica', 127, 146, 'GPE')]
# ['The', 'O', '']
# ['programming', 'O', '']
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The programming team who designed the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     HSE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  app to support coronavirus contact-tracing were found to have previously worked with
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cambridge Analytica
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ...

# %% [markdown]
# # SpaCy Named Entities - True News

# %% [markdown]
# 1 True

# %%
text = "A new study from Trinity College Dublin revealed that vitamin D is likely to reduce serious coronavirus complications. The researchers urged the government to advise Irish citizens to take daily vitamin D supplements."

nlp = spacy.load("en_core_web_sm")
doc = nlp(text)

# Named entities are available as the ents property of a Doc
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">A new study from
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Trinity College
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dublin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  revealed that vitamin D is likely to reduce serious coronavirus complications. The researchers urged the government to advise
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
# ...

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("A new study from Trinity College Dublin revealed that vitamin D is likely to reduce serious coronavirus complications. The researchers urged the government to advise Irish citizens to take daily vitamin D supplements.")

for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
    
    
displacy.render(doc, style="ent", jupyter=True,  options={'distance': 70})
# Out:
# Trinity College 17 32 ORG
# Dublin 33 39 GPE
# Irish 166 171 NORP
# daily 189 194 DATE
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">A new study from
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Trinity College
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dublin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  revealed that vitamin D is likely to reduce serious coronavirus complications. The researchers urged the government to advise
# ...

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("A new study from Trinity College Dublin revealed that vitamin D is likely to reduce serious coronavirus complications. The researchers urged the government to advise Irish citizens to take daily vitamin D supplements.")

# document level
ents = [(e.text, e.start_char, e.end_char, e.label_) for e in doc.ents]
print(ents)

# token level
ent_san = [doc[0].text, doc[0].ent_iob_, doc[0].ent_type_]
ent_francisco = [doc[1].text, doc[1].ent_iob_, doc[1].ent_type_]
print(ent_san)  # ['San', 'B', 'GPE']
print(ent_francisco)  # ['Francisco', 'I', 'GPE']

displacy.render(doc, style="ent", jupyter=True)
# Out:
# [('Trinity College', 17, 32, 'ORG'), ('Dublin', 33, 39, 'GPE'), ('Irish', 166, 171, 'NORP'), ('daily', 189, 194, 'DATE')]
# ['A', 'O', '']
# ['new', 'O', '']
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">A new study from
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Trinity College
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dublin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ...

# %% [markdown]
# 2 True

# %%
text = "Mixed-martial arts fighter Conor McGregor posted an online video urging the Irish government to enforce a complete lockdown, with the help of the army. I urge our government to utilise our defence forces he stated"

nlp = spacy.load("en_core_web_sm")
doc = nlp(text)

# Named entities are available as the ents property of a Doc
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Mixed-martial arts fighter
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Conor McGregor
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  posted an online video urging the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Irish
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  government to enforce a complete lockdown, with the help of the army. I urge our government to utilise our defence forces he stated</div></span>

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("Mixed-martial arts fighter Conor McGregor posted an online video urging the Irish government to enforce a complete lockdown, with the help of the army. I urge our government to utilise our defence forces he stated")

for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
    
    
displacy.render(doc, style="ent", jupyter=True,  options={'distance': 70})
# Out:
# Conor McGregor 27 41 PERSON
# Irish 76 81 NORP
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Mixed-martial arts fighter
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Conor McGregor
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  posted an online video urging the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Irish
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  government to enforce a complete lockdown, with the help of the army. I urge our government to utilise our defence forces he stated</div></span>

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("Mixed-martial arts fighter Conor McGregor posted an online video urging the Irish government to enforce a complete lockdown, with the help of the army. I urge our government to utilise our defence forces he stated.")

# document level
ents = [(e.text, e.start_char, e.end_char, e.label_) for e in doc.ents]
print(ents)

# token level
ent_san = [doc[0].text, doc[0].ent_iob_, doc[0].ent_type_]
ent_francisco = [doc[1].text, doc[1].ent_iob_, doc[1].ent_type_]
print(ent_san)  # ['San', 'B', 'GPE']
print(ent_francisco)  # ['Francisco', 'I', 'GPE']

displacy.render(doc, style="ent", jupyter=True)
# Out:
# [('Conor McGregor', 27, 41, 'PERSON'), ('Irish', 76, 81, 'NORP')]
# ['Mixed', 'O', '']
# ['-', 'O', '']
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Mixed-martial arts fighter
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Conor McGregor
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  posted an online video urging the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Irish
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
# ...

# %% [markdown]
# 3 True

# %%
text = "Sinn Féin President Mary Lou McDonald called off two Sinn Féin rallies in March, after a case of coronavirus was reported at her children's school"

nlp = spacy.load("en_core_web_sm")
doc = nlp(text)

# Named entities are available as the ents property of a Doc
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sinn Féin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mary Lou McDonald
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  called off
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
# ...

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("Sinn Féin President Mary Lou McDonald called off two Sinn Féin rallies in March, after a case of coronavirus was reported at her children's school")

for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
    
    
displacy.render(doc, style="ent", jupyter=True,  options={'distance': 70})
# Out:
# Sinn Féin 0 9 ORG
# Mary Lou McDonald 20 37 PERSON
# two 49 52 CARDINAL
# Sinn Féin 53 62 ORG
# March 74 79 DATE
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sinn Féin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mary Lou McDonald
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  called off
# ...

# %%
lp = spacy.load("en_core_web_sm")
doc = nlp("Sinn Féin President Mary Lou McDonald called off two Sinn Féin rallies in March, after a case of coronavirus was reported at her children's school.")

# document level
ents = [(e.text, e.start_char, e.end_char, e.label_) for e in doc.ents]
print(ents)

# token level
ent_san = [doc[0].text, doc[0].ent_iob_, doc[0].ent_type_]
ent_francisco = [doc[1].text, doc[1].ent_iob_, doc[1].ent_type_]
print(ent_san)  # ['San', 'B', 'GPE']
print(ent_francisco)  # ['Francisco', 'I', 'GPE']

displacy.render(doc, style="ent", jupyter=True)
# Out:
# [('Sinn Féin', 0, 9, 'ORG'), ('Mary Lou McDonald', 20, 37, 'PERSON'), ('two', 49, 52, 'CARDINAL'), ('Sinn Féin', 53, 62, 'ORG'), ('March', 74, 79, 'DATE')]
# ['Sinn', 'B', 'ORG']
# ['Féin', 'I', 'ORG']
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sinn Féin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mary Lou McDonald
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  called off
# ...

# %% [markdown]
# 4 True

# %%
lp = spacy.load("en_core_web_sm")
doc = nlp("As most of Europe is in lockdown, Sweden is pursuing a different strategy against COVID-19. Pubs, restaurants, gyms and most schools remain open in the Scandinavian state, with the government relying on personal responsibility for compliance rather than strict enforcement. Official guidance states that citizens may socialise, as long as they stay at arm’s length from each other.")

# document level
ents = [(e.text, e.start_char, e.end_char, e.label_) for e in doc.ents]
print(ents)

# token level
ent_san = [doc[0].text, doc[0].ent_iob_, doc[0].ent_type_]
ent_francisco = [doc[1].text, doc[1].ent_iob_, doc[1].ent_type_]
print(ent_san)  # ['San', 'B', 'GPE']
print(ent_francisco)  # ['Francisco', 'I', 'GPE']

displacy.render(doc, style="ent", jupyter=True)
# Out:
# [('Europe', 11, 17, 'LOC'), ('Sweden', 34, 40, 'GPE'), ('COVID-19.', 82, 91, 'ORG'), ('Scandinavian', 152, 164, 'NORP')]
# ['As', 'O', '']
# ['most', 'O', '']
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">As most of
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Europe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  is in lockdown,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sweden
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  is pursuing a different strategy against
# ...

# %% [markdown]
# # Examining the Fake News for Insights

# %% [markdown]
# # SpaCy Sentiment Analysis

# %% [markdown]
# # Fake News Data
#
# New research from Harvard University shows that the chemical in chilli peppers that causes the hot sensation in your mouth reduces the replication rate of coronaviruses. The researchers are currently investigating whether adding more spicy foods to your diet could help combat COVID-19.
#
# A study conducted in University College London found that those who drank more than 3 cups of coffee per day were less likely to suffer from severe Coronavirus symptoms. Researchers said they were conducting follow-up studies to better understand the links between caffeine and the immune system.
#
# A whistleblower report from a leading pharmaceutical company was leaked to the Guardian newspaper in April. The report stated that the coronavirus vaccine being developed by the company causes a high rate of complications, but that these concerns were being disregarded in favour of releasing the vaccine quickly.
#
# The programming team who designed the HSE app to support coronavirus contact-tracing were found to have previously worked with Cambridge Analytica, raising concerns about citizen’s data privacy. The app is designed to monitor people’s movements in order to support the government’s contact tracing initiative.
#
#  # True News Data
#
# A new study from Trinity College Dublin revealed that vitamin D is likely to reduce serious coronavirus complications. The researchers urged the government to advise Irish citizens totake daily vitamin D supplements.
#
# Mixed-martial arts fighter Conor McGregor posted an online video urging the Irish government to enforce a complete lockdown, with the help of the army. I urge our government to utilise our defence forces he stated.
#
# Sinn Féin President Mary Lou McDonald called off two Sinn Féin rallies in March, after a case of coronavirus was reported at her children's school.
#
# As most of Europe is in lockdown, Sweden is pursuing a different strategy against COVID-19. Pubs, restaurants, gyms and most schools remain open in the Scandinavian state, with the government relying on personal responsibility for compliance rather than strictenforcement. Official guidance states that citizens may socialise, as long as they stay at arm’s length from each other.

# %%
from textblob import TextBlob
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('brown')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# True

# %%
review = TextBlob("New research from Harvard University shows that the chemical in chilli peppers that causes the hot sensation in your mouth reduces the replication rate of coronaviruses. The researchers are currently investigating whether adding more spicy foods to your diet could help combat COVID-19.")

# %%
review.tags
# Out:
# [('New', 'NNP'),
#  ('research', 'NN'),
#  ('from', 'IN'),
#  ('Harvard', 'NNP'),
#  ('University', 'NNP'),
#  ('shows', 'VBZ'),
#  ('that', 'IN'),
#  ('the', 'DT'),
#  ('chemical', 'NN'),
#  ('in', 'IN'),
#  ('chilli', 'NN'),
#  ('peppers', 'NNS'),
#  ('that', 'WDT'),
#  ('causes', 'VBZ'),
#  ('the', 'DT'),
#  ('hot', 'JJ'),
#  ('sensation', 'NN'),
#  ('in', 'IN'),
#  ('your', 'PRP$'),
#  ('mouth', 'NN'),
#  ('reduces', 'VBZ'),
#  ('the', 'DT'),
#  ('replication', 'NN'),
#  ('rate', 'NN'),
#  ('of', 'IN'),
#  ('coronaviruses', 'NNS'),
#  ('The', 'DT'),
#  ('researchers', 'NNS'),
#  ('are', 'VBP'),
#  ('currently', 'RB'),
#  ('investigating', 'VBG'),
#  ('whether', 'IN'),
#  ('adding', 'VBG'),
#  ('more', 'JJR'),
#  ('spicy', 'NN'),
#  ('foods', 'NNS'),
#  ('to', 'TO'),
#  ('your', 'PRP$'),
#  ('diet', 'NN'),
#  ('could', 'MD'),
#  ('help', 'VB'),
#  ('combat', 'VB'),
#  ('COVID-19', 'NNP')]

# %%
review.noun_phrases
# Out:
# WordList(['new research', 'harvard', 'university shows', 'chilli peppers', 'hot sensation', 'mouth reduces', 'replication rate', 'spicy foods', 'covid-19'])

# %% [markdown]
# # TEST on testimonial  (fake news)

# %%
testimonial = TextBlob("New research from Harvard University shows that the chemical in chilli peppers that causes the hot sensation in your mouth reduces the replication rate of coronaviruses. The researchers are currently investigating whether adding more spicy foods to your diet could help combat COVID-19.")

# %%
testimonial.sentiment
# Out:
# Sentiment(polarity=0.2215909090909091, subjectivity=0.5511363636363636)

# %% [markdown]
# #Sentiment of all FOUR FAKE News Combined

# %%
fake_news = TextBlob("New research from Harvard University shows that the chemical in chilli peppers that causes the hot sensation in your mouth reduces the replication rate of coronaviruses. The researchers are currently investigating whether adding more spicy foods to your diet could help combat COVID-19. \
   A study conducted in University College London found that those who drank more than 3 cups of coffee per day were less likely to suffer from severe Coronavirus symptoms. Researchers said they were conducting follow-up studies to better understand the links between caffeine and the immune system. \
          A whistleblower report from a leading pharmaceutical company was leaked to the Guardian newspaper in April. The report stated that the coronavirus vaccine being developed by the company causes a high rate of complications, but that these concerns were being disregarded in favour of releasing the vaccine quickly. \
                          The programming team who designed the HSE app to support coronavirus contact-tracing were found to have previously worked with Cambridge Analytica, raising concerns about citizen’s data privacy. The app is designed to monitor people’s movements in order to support the government’s contact tracing initiative.") 
fake_news.words

fake_news.sentences
# Out:
# [Sentence("New research from Harvard University shows that the chemical in chilli peppers that causes the hot sensation in your mouth reduces the replication rate of coronaviruses."),
#  Sentence("The researchers are currently investigating whether adding more spicy foods to your diet could help combat COVID-19."),
#  Sentence("A study conducted in University College London found that those who drank more than 3 cups of coffee per day were less likely to suffer from severe Coronavirus symptoms."),
#  Sentence("Researchers said they were conducting follow-up studies to better understand the links between caffeine and the immune system."),
#  Sentence("A whistleblower report from a leading pharmaceutical company was leaked to the Guardian newspaper in April."),
#  Sentence("The report stated that the coronavirus vaccine being developed by the company causes a high rate of complications, but that these concerns were being disregarded in favour of releasing the vaccine quickly."),
# ...

# %%
for sentence in fake_news.sentences:
    print(sentence.sentiment)
# Out:
# Sentiment(polarity=0.19318181818181818, subjectivity=0.6522727272727273)
# Sentiment(polarity=0.25, subjectivity=0.45)
# Sentiment(polarity=0.11111111111111112, subjectivity=0.5222222222222223)
# Sentiment(polarity=0.5, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.19777777777777775, subjectivity=0.4466666666666666)
# Sentiment(polarity=-0.16666666666666666, subjectivity=0.16666666666666666)
# Sentiment(polarity=0.0, subjectivity=0.0)

# %% [markdown]
# #Sentiment of EACH OF the FOUR FAKE NewS

# %%
from spacytextblob.spacytextblob import SpacyTextBlob

nlp = spacy.load('en_core_web_sm')
nlp.add_pipe('spacytextblob')
text = "New research from Harvard University shows that the chemical in chilli peppers that causes the hot sensation in your mouth reduces the replication rate of coronaviruses. The researchers are currently investigating whether adding more spicy foods to your diet could help combat COVID-19"
doc = nlp(text)

# %% [markdown]
# Return a tuple of form (polarity, subjectivity ) where polarity is a float within the range [-1.0, 1.0] and subjectivity is a float within the range [0.0, 1.0] where 0.0 is very objective and 1.0 is very subjective.

# %%
print('Polarity {}'.format(doc._.polarity))
# Out:
# Polarity 0.2215909090909091

# %%
print('Subjectivity {}'.format(doc._.subjectivity))
# Out:
# Subjectivity 0.5511363636363636

# %%
print('Assessments {}'.format(doc._.assessments))
# Out:
# Assessments [(['new'], 0.13636363636363635, 0.45454545454545453, None), (['hot'], 0.25, 0.8500000000000001, None), (['currently'], 0.0, 0.4, None), (['more'], 0.5, 0.5, None)]

# %%
from spacytextblob.spacytextblob import SpacyTextBlob

nlp = spacy.load('en_core_web_sm')
nlp.add_pipe('spacytextblob')
text = "A study conducted in University College London found that those who drank more than 3 cups of coffee per day were less likely to suffer from severe Coronavirus symptoms. Researchers said they were conducting follow-up studies to better understand the links between caffeine and the immune system."
doc = nlp(text)

# %%
print('Polarity {}'.format(doc._.polarity))
# Out:
# Polarity 0.20833333333333334

# %%
print('Subjectivity {}'.format(doc._.subjectivity))
# Out:
# Subjectivity 0.5166666666666666

# %%
print('Assessments {}'.format(doc._.assessments))
# Out:
# Assessments [(['more'], 0.5, 0.5, None), (['less'], -0.16666666666666666, 0.06666666666666667, None), (['likely'], 0.0, 1.0, None), (['better'], 0.5, 0.5, None)]

# %%
from spacytextblob.spacytextblob import SpacyTextBlob

nlp = spacy.load('en_core_web_sm')
nlp.add_pipe('spacytextblob')
text = "A whistleblower report from a leading pharmaceutical company was leaked to the Guardian newspaper in April. The report stated that the coronavirus vaccine being developed by the company causes a high rate of complications, but that these concerns were being disregarded in favour of releasing the vaccine quickly."
doc = nlp(text)

# %%
print('Polarity {}'.format(doc._.polarity))
# Out:
# Polarity 0.19777777777777775

# %%
print('Subjectivity {}'.format(doc._.subjectivity))
# Out:
# Subjectivity 0.4466666666666666

# %%
print('Assessments {}'.format(doc._.assessments))
# Out:
# Assessments [(['developed'], 0.1, 0.3, None), (['high'], 0.16, 0.5399999999999999, None), (['quickly'], 0.3333333333333333, 0.5, None)]

# %%
from spacytextblob.spacytextblob import SpacyTextBlob

nlp = spacy.load('en_core_web_sm')
nlp.add_pipe('spacytextblob')
text = "The programming team who designed the HSE app to support coronavirus contact-tracing were found to have previously worked with Cambridge Analytica, raising concerns about citizen’s data privacy. The app is designed to monitor people’s movements in order to support the government’s contact tracing initiative."
doc = nlp(text)

# %%
print('Polarity {}'.format(doc._.polarity))
# Out:
# Polarity -0.16666666666666666

# %%
print('Subjectivity {}'.format(doc._.subjectivity))
# Out:
# Subjectivity 0.16666666666666666

# %%
print('Assessments {}'.format(doc._.assessments))
# Out:
# Assessments [(['previously'], -0.16666666666666666, 0.16666666666666666, None)]

# %% [markdown]
# #Comparing sentences fake news

# %% [markdown]
# Comparing 2 first  Fake News

# %%
first_user = nlp("New research from Harvard University shows that the chemical in chilli peppers that causes the hot sensation in your mouth reduces the replication rate of coronaviruses. The researchers are currently investigating whether adding more spicy foods to your diet could help combat COVID-19.")
second_user = nlp("A study conducted in University College London found that those who drank more than 3 cups of coffee per day were less likely to suffer from severe Coronavirus symptoms. Researchers said they were conducting follow-up studies to better understand the links between caffeine and the immune system.")

# Similarity of two documents
print(first_user, "<->", second_user, first_user.similarity(second_user))
# Out:
# New research from Harvard University shows that the chemical in chilli peppers that causes the hot sensation in your mouth reduces the replication rate of coronaviruses. The researchers are currently investigating whether adding more spicy foods to your diet could help combat COVID-19. <-> A study conducted in University College London found that those who drank more than 3 cups of coffee per day were less likely to suffer from severe Coronavirus symptoms. Researchers said they were conducting follow-up studies to better understand the links between caffeine and the immune system. 0.8212565701103325
# ...

# %% [markdown]
# Comparing 2 last Fake News

# %%
first_user = nlp(" A whistleblower report from a leading pharmaceutical company was leaked to the Guardian newspaper in April. The report stated that the coronavirus vaccine being developed by the company causes a high rate of complications, but that these concerns were being disregarded in favour of releasing the vaccine quickly.")
second_user = nlp("The programming team who designed the HSE app to support coronavirus contact-tracing were found to have previously worked with Cambridge Analytica, raising concerns about citizen’s data privacy. The app is designed to monitor people’s movements in order to support the government’s contact tracing initiative")

# Similarity of two documents
print(first_user, "<->", second_user, first_user.similarity(second_user))
# Out:
#  A whistleblower report from a leading pharmaceutical company was leaked to the Guardian newspaper in April. The report stated that the coronavirus vaccine being developed by the company causes a high rate of complications, but that these concerns were being disregarded in favour of releasing the vaccine quickly. <-> The programming team who designed the HSE app to support coronavirus contact-tracing were found to have previously worked with Cambridge Analytica, raising concerns about citizen’s data privacy. The app is designed to monitor people’s movements in order to support the government’s contact tracing initiative 0.7440635586853616
# ...

# %% [markdown]
# #Sentiment of all FOUR TRUE News Combined

# %%
true_news = TextBlob("A new study from Trinity College Dublin revealed that vitamin D is likely to reduce serious coronavirus complications. The researchers urged the government to advise Irish citizens totake daily vitamin D supplements. \
   Mixed-martial arts fighter Conor McGregor posted an online video urging the Irish government to enforce a complete lockdown, with the help of the army. I urge our government to utilise our defence forces he stated. \
          Sinn Féin President Mary Lou McDonald called off two Sinn Féin rallies in March, after a case of coronavirus was reported at her children's school. \
                          As most of Europe is in lockdown, Sweden is pursuing a different strategy against COVID-19. Pubs, restaurants, gyms and most schools remain open in the Scandinavian state, with the government relying on personal responsibility for compliance rather than strictenforcement. Official guidance states that citizens may socialise, as long as they stay at arm’s length from each other.") 
true_news.words

true_news.sentences
# Out:
# [Sentence("A new study from Trinity College Dublin revealed that vitamin D is likely to reduce serious coronavirus complications."),
#  Sentence("The researchers urged the government to advise Irish citizens totake daily vitamin D supplements."),
#  Sentence("Mixed-martial arts fighter Conor McGregor posted an online video urging the Irish government to enforce a complete lockdown, with the help of the army."),
#  Sentence("I urge our government to utilise our defence forces he stated."),
#  Sentence("Sinn Féin President Mary Lou McDonald called off two Sinn Féin rallies in March, after a case of coronavirus was reported at her children's school."),
#  Sentence("As most of Europe is in lockdown, Sweden is pursuing a different strategy against COVID-19."),
#  Sentence("Pubs, restaurants, gyms and most schools remain open in the Scandinavian state, with the government relying on personal responsibility for compliance rather than strictenforcement."),
# ...

# %%
for sentence in true_news.sentences:
    print(sentence.sentiment)
# Out:
# Sentiment(polarity=-0.06565656565656565, subjectivity=0.7070707070707071)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.05, subjectivity=0.2)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.25, subjectivity=0.55)
# Sentiment(polarity=0.16666666666666666, subjectivity=0.43333333333333335)
# Sentiment(polarity=-0.0875, subjectivity=0.3875)

# %% [markdown]
# #Sentiment of EACH OF THE FOUR TRUE News

# %%
from spacytextblob.spacytextblob import SpacyTextBlob

nlp = spacy.load('en_core_web_sm')
nlp.add_pipe('spacytextblob')
text = "A new study from Trinity College Dublin revealed that vitamin D is likely to reduce serious coronavirus complications. The researchers urged the government to advise Irish citizens totake daily vitamin D supplements"
doc = nlp(text)

# %% [markdown]
# Return a tuple of form (polarity, subjectivity ) where polarity is a float within the range [-1.0, 1.0] and subjectivity is a float within the range [0.0, 1.0] where 0.0 is very objective and 1.0 is very subjective.

# %%
print('Polarity {}'.format(doc._.polarity))
# Out:
# Polarity -0.03939393939393939

# %%
print('Subjectivity {}'.format(doc._.subjectivity))
# Out:
# Subjectivity 0.4242424242424242

# %%
print('Assessments {}'.format(doc._.assessments))
# Out:
# Assessments [(['new'], 0.13636363636363635, 0.45454545454545453, None), (['likely'], 0.0, 1.0, None), (['serious'], -0.3333333333333333, 0.6666666666666666, None), (['irish'], 0.0, 0.0, None), (['daily'], 0.0, 0.0, None)]

# %%
from spacytextblob.spacytextblob import SpacyTextBlob

nlp = spacy.load('en_core_web_sm')
nlp.add_pipe('spacytextblob')
text = "Mixed-martial arts fighter Conor McGregor posted an online video urging the Irish government to enforce a complete lockdown, with the help of the army. I urge our government to utilise our defence forces he stated."
doc = nlp(text)

# %%
print('Polarity {}'.format(doc._.polarity))
# Out:
# Polarity 0.05

# %%
print('Subjectivity {}'.format(doc._.subjectivity))
# Out:
# Subjectivity 0.2

# %%
print('Assessments {}'.format(doc._.assessments))
# Out:
# Assessments [(['irish'], 0.0, 0.0, None), (['complete'], 0.1, 0.4, None)]

# %%
from spacytextblob.spacytextblob import SpacyTextBlob

nlp = spacy.load('en_core_web_sm')
nlp.add_pipe('spacytextblob')
text = "Sinn Féin President Mary Lou McDonald called off two Sinn Féin rallies in March, after a case of coronavirus was reported at her children's school."
doc = nlp(text)

# %%
print('Polarity {}'.format(doc._.polarity))
# Out:
# Polarity 0.0

# %%
print('Subjectivity {}'.format(doc._.subjectivity))
# Out:
# Subjectivity 0.0

# %%
print('Assessments {}'.format(doc._.assessments))
# Out:
# Assessments []

# %%
from spacytextblob.spacytextblob import SpacyTextBlob

nlp = spacy.load('en_core_web_sm')
nlp.add_pipe('spacytextblob')
text = "As most of Europe is in lockdown, Sweden is pursuing a different strategy against COVID-19. Pubs, restaurants, gyms and most schools remain open in the Scandinavian state, with the government relying on personal responsibility for compliance rather than strictenforcement. Official guidance states that citizens may socialise, as long as they stay at arm’s length from each other.."
doc = nlp(text)

# %%
print('Polarity {}'.format(doc._.polarity))
# Out:
# Polarity 0.11785714285714285

# %%
print('Subjectivity {}'.format(doc._.subjectivity))
# Out:
# Subjectivity 0.45357142857142857

# %%
print('Assessments {}'.format(doc._.assessments))
# Out:
# Assessments [(['most'], 0.5, 0.5, None), (['different'], 0.0, 0.6, None), (['most'], 0.5, 0.5, None), (['open'], 0.0, 0.5, None), (['personal'], 0.0, 0.3, None), (['long'], -0.05, 0.4, None), (['other'], -0.125, 0.375, None)]

# %% [markdown]
# #Comparing sentences true news / Similarities

# %% [markdown]
# Comparing two first True News

# %%
first_user = nlp("A new study from Trinity College Dublin revealed that vitamin D is likely to reduce serious coronavirus complications. The researchers urged the government to advise Irish citizens totake daily vitamin D supplements.")
second_user = nlp("Mixed-martial arts fighter Conor McGregor posted an online video urging the Irish government to enforce a complete lockdown, with the help of the army. I urge our government to utilise our defence forces he stated.")

# Similarity of two documents
print(first_user, "<->", second_user, first_user.similarity(second_user))
# Out:
# A new study from Trinity College Dublin revealed that vitamin D is likely to reduce serious coronavirus complications. The researchers urged the government to advise Irish citizens totake daily vitamin D supplements. <-> Mixed-martial arts fighter Conor McGregor posted an online video urging the Irish government to enforce a complete lockdown, with the help of the army. I urge our government to utilise our defence forces he stated. 0.8498588491791155
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   """

# %% [markdown]
# Comparing two last True News

# %%
first_user = nlp("Sinn Féin President Mary Lou McDonald called off two Sinn Féin rallies in March, after a case of coronavirus was reported at her children's school.")
second_user = nlp("As most of Europe is in lockdown, Sweden is pursuing a different strategy against COVID-19.Pubs, restaurants, gyms and most schools remain open in the Scandinavian state, with thegovernment relying on personal responsibility for compliance rather than strictenforcement. Official guidance states that citizens may socialise, as long as they stay at arm’s length from each other.")

# Similarity of two documents
print(first_user, "<->", second_user, first_user.similarity(second_user))
# Out:
# Sinn Féin President Mary Lou McDonald called off two Sinn Féin rallies in March, after a case of coronavirus was reported at her children's school. <-> As most of Europe is in lockdown, Sweden is pursuing a different strategy against COVID-19.Pubs, restaurants, gyms and most schools remain open in the Scandinavian state, with thegovernment relying on personal responsibility for compliance rather than strictenforcement. Official guidance states that citizens may socialise, as long as they stay at arm’s length from each other. 0.5110144557746188
# ...

# %% [markdown]
# #Comparing sentences True news x False News (Similarities)

# %%
first_user = nlp("New research from Harvard University shows that the chemical in chilli peppers that causes the hot sensation in your mouth reduces the replication rate of coronaviruses. The researchers are currently investigating whether adding more spicy foods to your diet could help combat COVID-19.")
second_user = nlp("A new study from Trinity College Dublin revealed that vitamin D is likely to reduce serious coronavirus complications. The researchers urged the government to advise Irish citizens totake daily vitamin D supplements.")

# Similarity of two documents
print(first_user, "<->", second_user, first_user.similarity(second_user))
# Out:
# New research from Harvard University shows that the chemical in chilli peppers that causes the hot sensation in your mouth reduces the replication rate of coronaviruses. The researchers are currently investigating whether adding more spicy foods to your diet could help combat COVID-19. <-> A new study from Trinity College Dublin revealed that vitamin D is likely to reduce serious coronavirus complications. The researchers urged the government to advise Irish citizens totake daily vitamin D supplements. 0.789384125625461
# ...

# %%
first_user = nlp("A study conducted in University College London found that those who drank more than 3 cups of coffee per day were less likely to suffer from severe Coronavirus symptoms. Researchers said they were conducting follow-up studies to better understand the links between caffeine and the immune system.")
second_user = nlp("Mixed-martial arts fighter Conor McGregor posted an online video urging the Irish government to enforce a complete lockdown, with the help of the army. I urge our government to utilise our defence forces he stated.")

# Similarity of two documents
print(first_user, "<->", second_user, first_user.similarity(second_user))
# Out:
# A study conducted in University College London found that those who drank more than 3 cups of coffee per day were less likely to suffer from severe Coronavirus symptoms. Researchers said they were conducting follow-up studies to better understand the links between caffeine and the immune system. <-> Mixed-martial arts fighter Conor McGregor posted an online video urging the Irish government to enforce a complete lockdown, with the help of the army. I urge our government to utilise our defence forces he stated. 0.6987489354194732
# ...

# %%
first_user = nlp("A whistleblower report from a leading pharmaceutical company was leaked to the Guardian newspaper in April. The report stated that the coronavirus vaccine being developed by the company causes a high rate of complications, but that these concerns were being disregarded in favour of releasing the vaccine quickly.")
second_user = nlp("Sinn Féin President Mary Lou McDonald called off two Sinn Féin rallies in March, after a case of coronavirus was reported at her children's school.")

# Similarity of two documents
print(first_user, "<->", second_user, first_user.similarity(second_user))
# Out:
# A whistleblower report from a leading pharmaceutical company was leaked to the Guardian newspaper in April. The report stated that the coronavirus vaccine being developed by the company causes a high rate of complications, but that these concerns were being disregarded in favour of releasing the vaccine quickly. <-> Sinn Féin President Mary Lou McDonald called off two Sinn Féin rallies in March, after a case of coronavirus was reported at her children's school. 0.5627928803654185
# ...

# %%
first_user = nlp("The programming team who designed the HSE app to support coronavirus contact-tracing were found to have previously worked with Cambridge Analytica, raising concerns about citizen’s data privacy. The app is designed to monitor people’s movements in order to support the government’s contact tracing initiative.")
second_user = nlp("As most of Europe is in lockdown, Sweden is pursuing a different strategy against COVID-19. Pubs, restaurants, gyms and most schools remain open in the Scandinavian state, with the government relying on personal responsibility for compliance rather than strictenforcement. Official guidance states that citizens may socialise, as long as they stay at arm’s length from each other.")

# Similarity of two documents
print(first_user, "<->", second_user, first_user.similarity(second_user))
# Out:
# The programming team who designed the HSE app to support coronavirus contact-tracing were found to have previously worked with Cambridge Analytica, raising concerns about citizen’s data privacy. The app is designed to monitor people’s movements in order to support the government’s contact tracing initiative. <-> As most of Europe is in lockdown, Sweden is pursuing a different strategy against COVID-19. Pubs, restaurants, gyms and most schools remain open in the Scandinavian state, with the government relying on personal responsibility for compliance rather than strictenforcement. Official guidance states that citizens may socialise, as long as they stay at arm’s length from each other. 0.5651749447920017
# ...

# %% [markdown]
# # End of NLP with SpaCy
